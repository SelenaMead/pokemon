# %%
import requests
import re



class Pokemon:
    calls = []
    base_url = 'https://pokeapi.co/api/v2/pokemon/'
    
    def __init__(self): 
        #self.api_version = f'data/{version}/weather'
        #self.api_key = '02435e511927d661b86684bcc096de53'
        self.data = None
        self.calls.append(self)
        
    def __repr__(self):
       return f'<APICall: works>'

    def deck(pokemon):
        cards = []
        cards.append(pokemon)
        print(cards)
    
    def types(deck):
        int = []
        
        
    def run(self, pokemon):
        print('Loading...')
        
        response = requests.get(f'{self.base_url}/{pokemon}')
        self.data = response.json()
    def pokemon_dictonary(self, pokemon_type, pokemon, pokemon_height, pokemon_weight, pokemon_ability):
         pokemon_dict = {"Name": pokemon.title(),
                        "Specialty": pokemon_type,
                        "Height": pokemon_height,
                        "Weight": pokemon_weight,
                        "Ability": pokemon_ability}
         return pokemon_dict
    #def specialties():
        #fire, water, grass, rock, electric, and other
        
        
pokedeck = Pokemon()    
poke = True       
pokemons= []   
poke_list = []
#specialties
fire = []
water = []
grass = []
rock = []
electric = []
other = []

new_bool = False

while poke == True: 
    new_bool = True
    pokemon = input("Which pokemon would you like to add to your pokedeck ").lower() 
    pokemons.append(pokemon)
    keep_going = input("Adding another pokemon? Y or N")
    pokedeck.data
    if keep_going == 'n':
        poke = False
        new_bool = False
    else: 
        poke = True


i = 0

while i < len(pokemons):
    #print(pokemons[i])
    pokedeck.run(pokemons[i])
    name = pokemons[i]
    pokedeck.calls
    pokedeck.data
    pokemon_type = pokedeck.data['types'][0]['type']['name']
    pokemon_height =  pokedeck.data['height']
    pokemon_weight = pokedeck.data['weight']
    pokemon_ability  = pokedeck.data["abilities"][0]["ability"]['name']
    poke_list.append(pokedeck.pokemon_dictonary(pokemon_type, name, pokemon_height, pokemon_weight, pokemon_ability))
    
    i += 1
    

    

    
    


    

    


#pokemon_type = pokedeck.data['types'][0]['type']['name']
#pokemon_height =  pokedeck.data['height']


#pokemon_type


#poke_list.append(pokedeck.pokemon_dictonary(pokemon_type, pokemon, pokemon_height))


#poke_list.append(pokedeck.pokemon_dictonary(pokemon_type, pokemon, pokemon_height))
poke_list

#how to pull specialty
for pokies in poke_list:
    special = pokies.get('Specialty')
    #print(special)
    if special == 'fire':
        fire.append(pokies)
    elif special == 'water':
        water.append(pokies)
    elif special == 'grass':
        grass.append(pokies)
    elif special == 'rock':
        rock.append(pokies)
    elif special == 'electric':
        electric.append(pokies)
    else: 
        other.append(pokies)
print("Fire pokemon: ", fire)
print("Water pokemon: ", water)
print("Grass pokemon: ", grass)
print("Rock pokemon: ", rock)
print("Electric pokemon: ", electric)
print("All other pokemon: ", other)
# Out:
# Which pokemon would you like to add to your pokedeck pikachu
# Adding another pokemon? Y or Ny
# Which pokemon would you like to add to your pokedeck eevee
# Adding another pokemon? Y or Nn
# Loading...
# Loading...
# Fire pokemon:  []
# Water pokemon:  []
# Grass pokemon:  []
# Rock pokemon:  []
# Electric pokemon:  [{'Name': 'Pikachu', 'Specialty': 'electric', 'Height': 4, 'Weight': 60, 'Ability': 'static'}]
# All other pokemon:  [{'Name': 'Eevee', 'Specialty': 'normal', 'Height': 3, 'Weight': 65, 'Ability': 'run-away'}]
